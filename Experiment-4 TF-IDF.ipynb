# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents=[
    "placement training is usefull",
    "hostel food quality needs improvement",
    "faculty explains concepts clearly"
]

print(documents)

vectorizer=TfidfVectorizer()
tfidf=vectorizer.fit_transform(documents)

words=vectorizer.get_feature_names_out()
print(words)

scores=tfidf.toarray()
print(scores)
# Out:
# ['placement training is usefull', 'hostel food quality needs improvement', 'faculty explains concepts clearly']
# ['clearly' 'concepts' 'explains' 'faculty' 'food' 'hostel' 'improvement'
#  'is' 'needs' 'placement' 'quality' 'training' 'usefull']
# [[0.        0.        0.        0.        0.        0.        0.
#   0.5       0.        0.5       0.        0.5       0.5      ]
#  [0.        0.        0.        0.        0.4472136 0.4472136 0.4472136
#   0.        0.4472136 0.        0.4472136 0.        0.       ]
#  [0.5       0.5       0.5       0.5       0.        0.        0.
#   0.        0.        0.        0.        0.        0.       ]]
